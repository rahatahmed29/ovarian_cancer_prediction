# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from mealpy.swarm_based.WOA import OriginalWOA
from mealpy.utils.problem import Problem
import time

# =======================
# Load dataset
# =======================
data = pd.read_csv("../Datasets/ovariantotal.csv")

# Assuming last column is the target
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

print("Dataset shape:", X.shape)
print("Target distribution:", np.bincount(y))

# =======================
# Fitness Function
# =======================
def fitness_func(solution):
    """
    Fitness function for WOA:
    - Runs 5-fold CV on XGBoost
    - Returns negative mean accuracy (because WOA minimizes)
    """
    # Unpack hyperparameters from solution
    n_estimators = int(solution[0])
    max_depth = int(solution[1])
    learning_rate = solution[2]
    subsample = solution[3]
    colsample_bytree = solution[4]
    min_child_weight = int(solution[5])
    gamma = int(solution[6])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []

    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        model = XGBClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            min_child_weight=min_child_weight,
            gamma=gamma,
            use_label_encoder=False,
            eval_metric='logloss',
            verbosity=0,
            random_state=42
        )

        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        acc = accuracy_score(y_val, preds)
        scores.append(acc)

    return -np.mean(scores)

# =======================
# Parameter Bounds
# =======================
# These correspond to:
# [n_estimators, max_depth, learning_rate, subsample, colsample_bytree, min_child_weight, gamma]
lb = [200, 4, 0.01, 0.8, 0.8, 1, 0]
ub = [600, 8, 0.1, 1.0, 1.0, 3, 1]

# =======================
# Define the Problem
# =======================
problem = Problem(
    fit_func=fitness_func,
    lb=lb,
    ub=ub,
    minmax="min",
    verbose=False
)
# =======================
# Run WOA Multiple Times (for stability)
# =======================

best_solutions = []
best_scores = []
n_runs = 5  # you can reduce to 3 if you want even faster run

for run in range(n_runs):
    print(f"\n=== Running WOA {run + 1}/{n_runs} ===")
    
    woa = OriginalWOA(epoch=30, pop_size=10)  # balanced for <10min runs
    best_solution, best_fitness = woa.solve(problem)
    
    best_solutions.append(best_solution)
    best_scores.append(-best_fitness)  # accuracy is negative in fitness
    
    print(f"Best solution run {run + 1}: {best_solution}, Acc={-best_fitness:.4f}")

# =======================
# Stability Report
# =======================
best_solutions = np.array(best_solutions)
param_names = [
    "n_estimators", "max_depth", "learning_rate",
    "subsample", "colsample_bytree", "min_child_weight", "gamma"
]

print("\n=== Stability Report ===")
for i, name in enumerate(param_names):
    vals = best_solutions[:, i]
    print(f"{name}: mean={np.mean(vals):.4f}, std={np.std(vals):.4f}, chosen={np.round(np.mean(vals),2)}")

print(f"\nAvg Accuracy across runs: {np.mean(best_scores):.4f} ± {np.std(best_scores):.4f}")
# Out:
# Dataset shape: (349, 49)
# Target distribution: [171 178]
# 2025/10/31 12:34:11 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: Solving single objective optimization problem.
# === Running WOA 1/5 ===
# 2025/10/31 12:34:29 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 1, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 9.76617 seconds
# 2025/10/31 12:34:39 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch:
PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: Solving single objective optimization problem.
# Best solution run 2: [6.00000000e+02 8.00000000e+00 8.34046084e-02 1.00000000e+00
#  1.00000000e+00 2.99131164e+00 1.00000000e+00], Acc=0.9198
#
# === Running WOA 3/5 ===
# 2025/10/31 12:47:46 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 1, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 12.92366 seconds
# 2025/10/31 12:47:59 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 2, Current best: -0.914120082815735, Global best: -0.914120082815735, Runtime: 12.61276 seconds
# 2025/10/31 12:48:13 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 3, Current best: -0.914120082815735, Global best: -0.914120082815735, Runtime: 13.97078 seconds
# 2025/10/31 12:48:25 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 4, Current best: -0.914120082815735, Global best: -0.914120082815735, Runtime: 12.08642 seconds
# 2025/10/31 12:48:38 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 5, Current best: -0.914120082815735, Global best: -0.914120082815735, Runtime: 12.48062 seconds
# 2025/10/31 12:48:49 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 6, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.92348 seconds
# 2025/10/31 12:49:02 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 7, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 13.04605 seconds
# 2025/10/31 12:49:14 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 8, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.14619 seconds
# 2025/10/31 12:49:27 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 9, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 12.90518 seconds
# 2025/10/31 12:49:37 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 10, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.73785 seconds
# 2025/10/31 12:49:50 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 11, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 12.71216 seconds
# 2025/10/31 12:50:00 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 12, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.06979 seconds
# 2025/10/31 12:50:10 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 13, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.43494 seconds
# 2025/10/31 12:50:19 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 14, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.92647 seconds
# 2025/10/31 12:50:30 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 15, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 10.61450 seconds
# 2025/10/31 12:50:40 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 16, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.52369 seconds
# 2025/10/31 12:50:50 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 17, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.92469 seconds
# 2025/10/31 12:50:59 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 18, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.67707 seconds
# 2025/10/31 12:51:09 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 19, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.47317 seconds
# 2025/10/31 12:51:18 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 20, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.40042 seconds
# 2025/10/31 12:51:28 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 21, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.53802 seconds
# 2025/10/31 12:51:37 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 22, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.76588 seconds
# 2025/10/31 12:51:47 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 23, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.51152 seconds
# 2025/10/31 12:51:57 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 24, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.66997 seconds
# 2025/10/31 12:52:06 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 25, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.53340 seconds
# 2025/10/31 12:52:16 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 26, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.54923 seconds
# 2025/10/31 12:52:25 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 27, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.17687 seconds
# 2025/10/31 12:52:34 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 28, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 9.63398 seconds
# 2025/10/31 12:52:45 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 29, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 10.15403 seconds
# 2025/10/31 12:52:55 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 30, Current best: -0.9255486542443064, Global best: -0.9255486542443064, Runtime: 10.32924 seconds
# 2025/10/31 12:52:55 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: Solving single objective optimization problem.
# Best solution run 3: [5.21212040e+02 8.00000000e+00 9.90520691e-02 1.00000000e+00
#  1.00000000e+00 2.82120694e+00 1.00000000e+00], Acc=0.9255
#
# === Running WOA 4/5 ===
# 2025/10/31 12:53:23 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 1, Current best: -0.9169772256728779, Global best: -0.9169772256728779, Runtime: 15.18805 seconds
# 2025/10/31 12:53:37 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 2, Current best: -0.9169772256728779, Global best: -0.9169772256728779, Runtime: 14.16704 seconds
# 2025/10/31 12:53:50 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 3, Current best: -0.9169772256728779, Global best: -0.9169772256728779, Runtime: 12.77544 seconds
# 2025/10/31 12:54:02 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 4, Current best: -0.9169772256728779, Global best: -0.9169772256728779, Runtime: 12.05098 seconds
# 2025/10/31 12:54:17 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 5, Current best: -0.9169772256728779, Global best: -0.9169772256728779, Runtime: 14.75006 seconds
# 2025/10/31 12:54:29 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 6, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 12.16377 seconds
# 2025/10/31 12:54:43 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 7, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 13.60772 seconds
# 2025/10/31 12:54:53 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 8, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.53367 seconds
# 2025/10/31 12:55:05 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 9, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.95864 seconds
# 2025/10/31 12:55:17 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 10, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 12.13328 seconds
# 2025/10/31 12:55:28 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 11, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.67704 seconds
# 2025/10/31 12:55:39 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 12, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.94965 seconds
# 2025/10/31 12:55:51 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 13, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.53952 seconds
# 2025/10/31 12:56:04 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 14, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 13.00566 seconds
# 2025/10/31 12:56:14 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 15, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.89125 seconds
# 2025/10/31 12:56:25 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 16, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.83516 seconds
# 2025/10/31 12:56:36 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 17, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.98615 seconds
# 2025/10/31 12:56:46 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 18, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.16256 seconds
# 2025/10/31 12:56:57 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 19, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.50146 seconds
# 2025/10/31 12:57:08 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 20, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.26090 seconds
# 2025/10/31 12:57:19 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 21, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.71142 seconds
# 2025/10/31 12:57:30 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 22, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.82708 seconds
# 2025/10/31 12:57:41 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 23, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.82805 seconds
# 2025/10/31 12:57:51 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 24, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.57782 seconds
# 2025/10/31 12:58:01 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 25, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.31497 seconds
# 2025/10/31 12:58:12 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 26, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.72919 seconds
# 2025/10/31 12:58:23 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 27, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.07730 seconds
# 2025/10/31 12:58:35 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 28, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.31724 seconds
# 2025/10/31 12:58:45 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 29, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 10.85240 seconds
# 2025/10/31 12:58:57 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 30, Current best: -0.9198343685300208, Global best: -0.9198343685300208, Runtime: 11.26901 seconds
# 2025/10/31 12:58:57 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: Solving single objective optimization problem.
# Best solution run 4: [6.00000000e+02 8.00000000e+00 8.29067119e-02 1.00000000e+00
#  1.00000000e+00 2.89354126e+00 1.00000000e+00], Acc=0.9198
#
# === Running WOA 5/5 ===
# 2025/10/31 12:59:22 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 1, Current best: -0.9082815734989648, Global best: -0.9082815734989648, Runtime: 13.28287 seconds
# 2025/10/31 12:59:33 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 2, Current best: -0.9082815734989648, Global best: -0.9082815734989648, Runtime: 10.58288 seconds
# 2025/10/31 12:59:44 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 3, Current best: -0.9083643892339545, Global best: -0.9083643892339545, Runtime: 11.77407 seconds
# 2025/10/31 12:59:58 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 4, Current best: -0.9083643892339545, Global best: -0.9083643892339545, Runtime: 13.65972 seconds
# 2025/10/31 01:00:12 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 5, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 14.14094 seconds
# 2025/10/31 01:00:23 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 6, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 10.67637 seconds
# 2025/10/31 01:00:37 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 7, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 13.93339 seconds
# 2025/10/31 01:00:48 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 8, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 11.16596 seconds
# 2025/10/31 01:01:04 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 9, Current best: -0.9112215320910974, Global best: -0.9112215320910974, Runtime: 15.81614 seconds
# 2025/10/31 01:01:15 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 10, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 10.91418 seconds
# 2025/10/31 01:01:27 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 11, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 12.45499 seconds
# 2025/10/31 01:01:40 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 12, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 12.96454 seconds
# 2025/10/31 01:01:52 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 13, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 12.02918 seconds
# 2025/10/31 01:02:06 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 14, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 13.65250 seconds
# 2025/10/31 01:02:17 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 15, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 10.98265 seconds
# 2025/10/31 01:02:28 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 16, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 11.35333 seconds
# 2025/10/31 01:02:40 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 17, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 11.45410 seconds
# 2025/10/31 01:02:52 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 18, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 12.07887 seconds
# 2025/10/31 01:03:03 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 19, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 11.19192 seconds
# 2025/10/31 01:03:14 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 20, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 11.14353 seconds
# 2025/10/31 01:03:25 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 21, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 10.96432 seconds
# 2025/10/31 01:03:36 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 22, Current best: -0.9140786749482401, Global best: -0.9140786749482401, Runtime: 10.93862 seconds
# 2025/10/31 01:03:47 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 23, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.15826 seconds
# 2025/10/31 01:03:58 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 24, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.12573 seconds
# 2025/10/31 01:04:10 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 25, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.35873 seconds
# 2025/10/31 01:04:21 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 26, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.40557 seconds
# 2025/10/31 01:04:32 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 27, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.04930 seconds
# 2025/10/31 01:04:43 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 28, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.29886 seconds
# 2025/10/31 01:04:55 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 29, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.31179 seconds
# 2025/10/31 01:05:06 PM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >Problem: P, Epoch: 30, Current best: -0.916935817805383, Global best: -0.916935817805383, Runtime: 11.64449 seconds
# Best solution run 5: [4.16793486e+02 5.19180711e+00 5.74508521e-02 9.98426507e-01
#  9.98434621e-01 2.90654267e+00 2.30860364e-01], Acc=0.9169
#
# === Stability Report ===
# n_estimators: mean=497.6537, std=99.7667, chosen=497.65
# max_depth: mean=6.7841, std=1.4964, chosen=6.78
# learning_rate: mean=0.0748, std=0.0178, chosen=0.07
# subsample: mean=0.9618, std=0.0755, chosen=0.96
# colsample_bytree: mean=0.9597, std=0.0798, chosen=0.96
# min_child_weight: mean=2.6204, std=0.5681, chosen=2.62
# gamma: mean=0.7571, std=0.3146, chosen=0.76
#
# Avg Accuracy across runs: 0.9198 ± 0.0032
